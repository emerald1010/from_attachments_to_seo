# %%
import numpy as np

# %% [markdown]
# ## Arrays for all metrics
#    ### outlier_dist: smallest distances to the rest of the data of the outlier sample
#
#    ### for instances that are parts of campaigns
#     #### smallest: smallest distances to the rest of the data for the instances that are parts of a campaign.
#     #### shift: distances at which the campaign flipped
#     #### recall_at_shift: number of correct instances before shift.
#     #### index i for the the three arrays corresponds to the same instance or data point.

# %%
vgg_outliers_dist = [15.15,30.84,19.29,10.19,8.72,38.34,15.02,11.82,9.93,25.68,16.15,28.4,18.91,12.18,7.06,12.5,7.61,29.62,12.336,17.22,26.55,20.37,6.69,24.41,15.61,12.81,15.17,18.15,10.98,17.8,24.01, 22.53,18.75,13.3,11.41,7.55,7.95,6.81,5.8,40.9,13.3,28.3,27.82,15.339,10.34,7.71,26.3,18.61]

vgg_smallest = [0.04, 0.085, 18.46, 5.12, 29.4, 2.23, 5.8, 8.88, 10.27, 10.89, 7.049, 0.59, 6.7, 22.65, 6.19, 2.59, 10.55, 6.62, 3.39, 17.33, 6.7, 3.35, 3.07, 9.6, 5.51, 5.24, 5.67, 8.05, 4.23, 7.33, 2.29, 3.21,3.2, 3.32, 9.03, 9.47, 9.48, 7.51, 1.905, 12.89, 19.5, 29.6, 37.9, 7.65, 4.88, 4.44]
vgg_shift = [11.07, 0.56, 31.67, 15.16, 32.4, 5.8, 11.1, 12.04, 13.3, 10.89, 10.85, 27.7, 14.52, 23.1, 23.62, 25.35, 12.9, 8.9, 4.84, 41.13, 8.62, 9.57, 8.16, 9.6, 10.39,12.44, 8.44, 9.88, 28.92, 32.5, 15.45, 6.75, 6.8, 6.84, 13.19, 14.01, 14.38, 7.75, 21.69, 12.89, 19.5, 29.6, 37.9, 15.65, 12.68, 12.59]
vgg_recall_at_shift = [29, 48, 68, 21, 40, 6748, 6, 1, 2, 0, 70, 160, 2, 2, 21, 13, 2, 22, 12 , 135, 9, 9, 997, 0, 1, 5, 28, 51, 74, 136, 10, 5, 2, 4, 5, 64, 4, 1, 2, 0, 0, 0, 0, 10, 13, 13]

# %%
dc_outliers_dist = [59, 49, 47, 51.9, 51.6, 56.0, 49, 51.2, 46, 40.9, 48.5, 46.4, 37.7, 55.9, 44.5, 46.5, 63, 31.6, 44.19, 53.4, 48, 43.2, 45.4, 48.5, 49.6, 55, 44.15, 51.74, 49.8, 54.9, 41, 46, 47, 87, 33, 50.35, 44.4, 44.5, 45.18, 46.5, 37.9, 43.5, 38.14, 52.07, 48.9, 45.9, 48.8, 54, 62]

dc_smallest = [0.19, 14.06, 27, 7.3, 33.23,64.7, 20.95, 35, 15.76, 20.3,  22.2,2.41, 17.33,  38.5,   18, 1.56,21.5, 27,
               5.85, 1.69, 13.99, 25, 12.16, 27, 33.3, 36, 20.92, 25, 8.55, 29.5, 8.3, 14.62, 24.84, 21.62, 2.44, 19.45, 
               1.8, 2.01, 10.87, 10.87, 24.97, 14.11, 22.6, 34.9, 24.3, 1.15, 23.7, 14.11, 23, 25.2, 38.3]

dc_shift = [51.5, 141, 42, 156, 74.21,  153,  145.65, 35, 50.6, 29.7, 136,  147, 26.56,  129,    100.41, 66.7,   46.6, 113,
            99.01, 70.4, 42, 87.27, 109, 172, 147, 135, 110, 153, 58.7, 155, 47, 46.6, 160, 158.8, 82.9, 
            53, 195, 47.3, 30.4, 44.11, 46.9, 46, 31.6, 40.9,
            62, 52.8, 49.14, 46.6,  47, 38, 53]

dc_recall_at_shift = [12, 63, 17, 22, 25,290,  24, 0,  7, 3,  25,  26,   2,   26, 18,   18,  2,41,
                      37, 26, 9, 7, 14, 621, 452, 465, 165, 261, 4,
                     238, 6, 15, 26, 26, 25, 11, 60, 10, 2, 9, 16, 12, 7, 3, 
                      7, 4, 5, 10, 7, 2, 4]

# %%
phash_outliers_dist = [7, 3, 9, 3, 4,21, 7, 3,5 , 14, 15, 1,6 ,11,1 , 10, 4, 17, 6,7,4 ,12, 5,10,7,6,11,3,6,1,4,1,9,3,10,5,7,14,10,10,1,6,7,2,1,4,3,7,7]

phash_smallest = [2, 1, 1, 4, 1, 1, 1, 12, 6, 2, 4, 1, 5,2 , 3, 1, 4, 1, 1, 3, 2, 4, 1, 1, 2, 2, 1, 1, 1, 
                  1, 1, 1, 3, 3, 2, 1, 1, 4, 1, 1, 1, 1, 1, 6, 7, 1, 1, 1, 3, 3, 2, 2]

phash_shift = [3, 3, 1, 14, 9, 6, 3, 12, 7, 7, 5, 6, 11, 4, 7, 14, 13, 4, 5, 17, 3, 4, 12, 9, 4, 6, 14, 8, 
               1,7,1,7, 8, 4,14, 3, 13, 1, 1, 1, 1, 1, 11, 7, 7, 2, 1, 5, 7, 6, 7]

phash_recall_at_shift = [2, 35, 0, 6, 1, 1080, 6, 0, 1, 3, 2, 57, 1, 3, 1, 3, 2, 10, 10, 3, 2, 0, 14, 1245, 4, 264, 1057, 613, 
                         0, 265, 0, 6, 12, 4, 2, 2, 2, 0, 0, 0, 0, 0, 886, 0, 3, 12, 0, 5, 1, 6, 3]

# %%
print(len(dc_recall_at_shift))
print(len(dc_shift))
print(len(dc_smallest))
# Out:
# 51
# 51
# 51

# %%
print(len(phash_recall_at_shift))
print(len(phash_shift))
print(len(phash_recall_at_shift))
# Out:
# 51
# 51
# 51

# %% [markdown]
# ## shift distance point histogram w.r.t. the mean of the smallest points (parts of campaigns)

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
ax.set_title('VGG')

hist_vgg,bins = np.histogram(vgg_shift,bins=90, density=True)
ax.bar(bins[0:len(hist_vgg)], hist_vgg, label = 'Distance @ Flip')
plt.axvline(x=np.mean(vgg_smallest),color = 'g', label='closest distance mean - similar')

plt.legend(loc='best',fontsize=15)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
ax.set_title('P. hash')

hist_phash,bins = np.histogram(phash_shift,bins=5, density=True)
ax.bar(bins[0:len(hist_phash)], hist_phash, label = 'Distance @ Flip')
plt.axvline(x=np.mean(phash_smallest),color = 'g', label='closest distance mean - similar')

plt.legend(loc='best',fontsize=15)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
ax.set_title('Deep cluster')

hist_dc,bins = np.histogram(dc_shift,bins=85,density=True)
ax.bar(bins[0:len(hist_dc)],  hist_dc, label = 'Distance @ Flip')
plt.axvline(x=np.mean(dc_smallest),color = 'g', label='closest distance mean - similar')

plt.legend(loc='best',fontsize=15)
plt.show()

# %% [markdown]
# ## shift distance point histogram w.r.t. the histogram of the smallest points (parts of campaigns)

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)

fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
ax.set_title('Deep cluster')

hist_shift,bins = np.histogram(dc_shift,bins=85,density=True)
hist_smallest,bins2 = np.histogram(dc_smallest,bins=85,density=True)
hist_outliers,bins3 = np.histogram(dc_outliers_dist,bins=85,density=True)


#ax.scatter(dc_shift,dc_recall_at_shift, label = 'True instances @ Flip')
ax.bar(bins2[0:len(hist_smallest)],  hist_smallest, alpha=0.6, label = 'Smallest distances - similar', color='tab:green')
#ax.bar(bins3[0:len(hist_outliers)],  hist_outliers, alpha=0.6, label = 'Smallest distances - outliers', color='tab:orange')
ax.bar(bins[0:len(hist_shift)],  hist_shift, label = 'Distance @ Flip', color='tab:blue')
plt.legend(loc='best',fontsize=15)
#plt.legend(bbox_to_anchor=(1.68, 0.85),fontsize=15)

#ax2=ax.twinx()
#ax2.scatter(dc_shift,dc_recall_at_shift, alpha=0.5, label = 'True instances @ Flip', color='tab:purple')
#ax2.set_ylabel('Count')


#plt.axvline(x=np.mean(dc_smallest),color = 'g', label='closest distance mean - similar')
#plt.axvline(x=np.mean(dc_outliers_dist),color = 'r', label='closest distance mean - outliers')

#plt.legend(bbox_to_anchor=(1.58, 0.98),fontsize=15)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
ax.set_title('VGG')

hist_shift,bins = np.histogram(vgg_shift,bins=85,density=True)
hist_smallest,bins2 = np.histogram(vgg_smallest,bins=85,density=True)
hist_outliers,bins3 = np.histogram(vgg_outliers_dist,bins=85,density=True)


#ax.scatter(dc_shift,dc_recall_at_shift, label = 'True instances @ Flip')
ax.bar(bins2[0:len(hist_smallest)],  hist_smallest, alpha=0.6, width=0.3, label = 'Smallest distances - similar', color='tab:green')
#ax.bar(bins3[0:len(hist_outliers)],  hist_outliers, alpha=0.6, width=0.3, label = 'Smallest distances - outliers', color='tab:orange')
ax.bar(bins[0:len(hist_shift)],  hist_shift, alpha=0.6, width=0.3, label = 'Distance @ Flip', color='tab:blue')
plt.legend(loc='best',fontsize=15)
#plt.legend(bbox_to_anchor=(1.68, 0.85),fontsize=15)

#ax2=ax.twinx()
#ax2.scatter(vgg_shift,vgg_recall_at_shift, alpha=0.6, label = 'True instances @ Flip', color='tab:purple')
#ax2.set_ylabel('Count')


#plt.axvline(x=np.mean(dc_smallest),color = 'g', label='closest distance mean - similar')
#plt.axvline(x=np.mean(dc_outliers_dist),color = 'r', label='closest distance mean - outliers')

#plt.legend(bbox_to_anchor=(1.58, 0.98),fontsize=15)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
ax.set_title('Perceptual hashing')

hist_shift,bins = np.histogram(phash_shift,bins=15,density=True)
hist_smallest,bins2 = np.histogram(phash_smallest,bins=15,density=True)
hist_outliers,bins3 = np.histogram(phash_outliers_dist,bins=15,density=True)


#ax.scatter(dc_shift,dc_recall_at_shift, label = 'True instances @ Flip')
ax.bar(bins2[0:len(hist_smallest)],  hist_smallest, alpha=0.6, width=0.3, label = 'Smallest distances - similar', color='tab:green')
#ax.bar(bins3[0:len(hist_outliers)],  hist_outliers, alpha=0.6, width=0.3, label = 'Smallest distances - outliers', color='tab:orange')
ax.bar(bins[0:len(hist_shift)],  hist_shift, alpha=0.6, width=0.3, label = 'Distance @ Flip', color='tab:blue')
plt.legend(loc='best',fontsize=15)
#plt.legend(bbox_to_anchor=(1.68, 0.85),fontsize=15)

#ax2=ax.twinx()
#ax2.scatter(vgg_shift,vgg_recall_at_shift, alpha=0.6, label = 'True instances @ Flip', color='tab:purple')
#ax2.set_ylabel('Count')


#plt.axvline(x=np.mean(dc_smallest),color = 'g', label='closest distance mean - similar')
#plt.axvline(x=np.mean(dc_outliers_dist),color = 'r', label='closest distance mean - outliers')

#plt.legend(bbox_to_anchor=(1.58, 0.98),fontsize=15)
plt.show()

# %% [markdown]
# ## scatter plots of shift distances vs. true points retrieved

# %%
plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
matplotlib.rc('axes', titlesize=17)
ax.set_title('VGG')

plt.scatter(vgg_shift,vgg_recall_at_shift)
ax.set_ylim([0,190])
#plt.axvline(x=np.mean(vgg_smallest),color = 'g', label='closest dist. mean - similar')
#plt.axvline(x=np.mean(vgg_outliers_dist),color = 'r', label='closest dist. mean - outliers')
plt.xlabel('Distance @ Flip')
plt.ylabel('Correct instances @ Flip')
#plt.legend(loc='best',fontsize=15)
# Out:
# Text(0, 0.5, 'Correct instances @ Flip')

# %%
plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
ax.set_title('Deep cluster')

matplotlib.rc('axes', titlesize=17)

plt.scatter(dc_shift,dc_recall_at_shift)
plt.xlabel('Distance @ Flip')
plt.ylabel('Correct instances @ Flip')
ax.set_ylim([0,190])
#plt.axvline(x=np.mean(dc_smallest),color = 'g', label='closest dist. mean - similar')
#plt.axvline(x=np.mean(dc_outliers_dist),color = 'r', label='closest dist. mean - outliers')
#plt.legend(loc='best',fontsize=15)
# Out:
# (0, 190)

# %%
np.mean(dc_smallest)
# Out:
# 19.394313725490193

# %%
plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))

matplotlib.rc('axes', titlesize=17)
ax = fig.add_subplot(1,1,1) 
ax.set_title('Perceptual hashing')
plt.xlabel('Distance @ Flip')
plt.ylabel('Correct instances @ Flip')
plt.scatter(phash_shift,phash_recall_at_shift)
ax.set_ylim([0,190])
#plt.axvline(x=np.mean(phash_smallest),color = 'g', label='closest dist. mean - similar')
#plt.axvline(x=np.mean(phash_outliers_dist),color = 'r', label='closest dist. mean - outliers')
#plt.legend(loc='best',fontsize=15)
# Out:
# (0, 190)

# %% [markdown]
# ## histogram of closest distances for outliers and images that are part of campaigns

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
ax.set_title('Deep cluster')

hist_dc_smallest,bins1 = np.histogram(dc_smallest,bins=100,density=True)
hist_dc_outliers,bins2 = np.histogram(dc_outliers_dist,bins=100,density=True)

ax.bar(bins1[0:len(hist_dc_smallest)],  hist_dc_smallest,  alpha = 0.8, label = 'Closest distance - similar campaigns')
ax.bar(bins2[0:len(hist_dc_outliers)],  hist_dc_outliers,  alpha = 0.8, label = 'Closest distance - outliers')
plt.legend(loc='best',fontsize=15)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
ax.set_title('VGG')

hist_vgg_smallest,bins1 = np.histogram(vgg_smallest,bins=100,density=True)
hist_vgg_outliers,bins2 = np.histogram(vgg_outliers_dist,bins=100,density=True)

ax.bar(bins1[0:len(hist_vgg_smallest)],  hist_vgg_smallest,  alpha = 0.8, width=0.3, label = 'Closest distance - similar campaigns')
ax.bar(bins2[0:len(hist_vgg_outliers)],  hist_vgg_outliers,  alpha = 0.8, width=0.3, label = 'Closest distance - outliers')
plt.legend(loc='best',fontsize=15)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot(1,1,1) 
ax.set_title('Perceptual hashing')

hist_phash_smallest,bins1 = np.histogram(phash_smallest,bins=15,density=True)
hist_phash_outliers,bins2 = np.histogram(phash_outliers_dist,bins=15,density=True)

ax.bar(bins1[0:len(hist_phash_smallest)],  hist_phash_smallest,  width=0.3, alpha = 0.8, label = 'Closest distance - similar campaigns')
ax.bar(bins2[0:len(hist_phash_outliers)],  hist_phash_outliers,  width=0.3, alpha = 0.8, label = 'Closest distance - outliers')
plt.legend(loc='best',fontsize=15)
plt.show()
